# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanrajs/distribution_factors_pySR/blob/main/df_PySR_PSC_V_G2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Symbolic Regression

# %%
# %%shell
# set -e
#
# #---------------------------------------------------#
# JULIA_VERSION="1.8.5"
# export JULIA_PKG_PRECOMPILE_AUTO=0
# #---------------------------------------------------#
#
# if [ -z `which julia` ]; then
#   # Install Julia
#   JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
#   echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
#   BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
#   URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
#   wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
#   tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
#   rm /tmp/julia.tar.gz
#
#   echo "Installing PyCall.jl..."
#   julia -e 'using Pkg; Pkg.add("PyCall"); Pkg.build("PyCall")'
#   julia -e 'println("Success")'
#
# fi
# Out:
# Installing Julia 1.8.5 on the current Colab Runtime...
# 2024-06-12 20:33:38 URL:https://storage.googleapis.com/julialang2/bin/linux/x64/1.8/julia-1.8.5-linux-x86_64.tar.gz [130873886/130873886] -> "/tmp/julia.tar.gz" [1]
# Installing PyCall.jl...
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed VersionParsing ── v1.3.0
#    Installed Conda ─────────── v1.10.0
#    Installed MacroTools ────── v0.5.13
#    Installed JSON ──────────── v0.21.4
#    Installed Preferences ───── v1.4.3
#    Installed Parsers ───────── v2.8.1
#    Installed PrecompileTools ─ v1.2.1
#    Installed PyCall ────────── v1.96.4
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [438e738f] + PyCall v1.96.4
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [8f4d0f93] + Conda v1.10.0
#   [682c06a0] + JSON v0.21.4
#   [1914dd2f] + MacroTools v0.5.13
#   [69de0a69] + Parsers v2.8.1
#   [aea7be01] + PrecompileTools v1.2.1
#   [21216c6a] + Preferences v1.4.3
#   [438e738f] + PyCall v1.96.4
#   [81def892] + VersionParsing v1.3.0
#   [0dad84c5] + ArgTools v1.1.1
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [f43a241f] + Downloads v1.6.0
#   [7b1f6079] + FileWatching
#   [b27032c2] + LibCURL v0.6.3
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions v1.2.0
#   [de0858da] + Printf
#   [9a3f8284] + Random
#   [ea8e919c] + SHA v0.7.0
#   [9e88b42a] + Serialization
#   [fa267f1f] + TOML v1.0.0
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [deac9b47] + LibCURL_jll v7.84.0+0
#   [29816b5a] + LibSSH2_jll v1.10.2+0
#   [c8ffd9c3] + MbedTLS_jll v2.28.0+0
#   [14a3606d] + MozillaCACerts_jll v2022.2.1
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [83775a58] + Zlib_jll v1.2.12+3
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#   [8e850ede] + nghttp2_jll v1.48.0+0
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/9816a3826b0ebf49ab4926e2b18842ad8b5c8f04/build.log`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/9816a3826b0ebf49ab4926e2b18842ad8b5c8f04/build.log`
# Success

# %% [markdown]
# Install PySR and PyTorch-Lightning:

# %%
# %pip install -Uq pysr pytorch_lightning --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.3/76.3 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.3/802.3 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 53.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 44.6 MB/s eta 0:00:00

# %%
# %pip install julia
# Out:
# Collecting julia
#   Downloading julia-0.6.2-py2.py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: julia
# Successfully installed julia-0.6.2

# %%
from julia import Julia

julia = Julia(compiled_modules=False, threads="auto")
from julia import Main
from julia.tools import redirect_output_streams

redirect_output_streams()

# %%
import pysr

# We don't precompile in colab because compiled modules are incompatible static Python libraries:
pysr.install(precompile=False)
# Out:
# [juliapkg] Found dependencies: /usr/local/lib/python3.10/dist-packages/juliacall/juliapkg.json
# [juliapkg] Found dependencies: /usr/local/lib/python3.10/dist-packages/pysr/juliapkg.json
# [juliapkg] Found dependencies: /usr/local/lib/python3.10/dist-packages/juliapkg/juliapkg.json
# [juliapkg] Locating Julia ~1.6.7, ~1.7, ~1.8, ~1.9, =1.10.0, ^1.10.3
# [juliapkg] Using Julia 1.8.5 at /usr/local/bin/julia
# [juliapkg] Using Julia project at /root/.julia/environments/pyjuliapkg
# [juliapkg] Installing packages:
#            julia> import Pkg
#            julia> Pkg.Registry.update()
#            julia> Pkg.add([Pkg.PackageSpec(name="PythonCall", uuid="6099a3de-0909-46bc-b1f4-468b9a2dfc0d"), Pkg.PackageSpec(name="SymbolicRegression", uuid="8254be44-1295-4e6a-a16d-46603ac705cb"), Pkg.PackageSpec(name="Serialization", uuid="9e88b42a-f829-5b0c-bbe9-9e923198166b")])
#            julia> Pkg.resolve()
#            julia> Pkg.precompile()

# %%
import sympy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
df = pd.read_csv('https://raw.githubusercontent.com/bhushanrajs/distribution_factors_pySR/main/skew_0.csv')

# %%
print(df.head(5))
# Out:
#                              model girderName     L     D  w_oh    ts    S  \
# 0   Tx28-L_42-Nb_4-S_60-O_15-ts_85       Tx28  42.0  28.0   1.5   8.5  6.0
# 1  Tx28-L_42-Nb_4-S_60-O_15-ts_100       Tx28  42.0  28.0   1.5  10.0  6.0
# 2   Tx28-L_42-Nb_4-S_60-O_20-ts_85       Tx28  42.0  28.0   2.0   8.5  6.0
# 3  Tx28-L_42-Nb_4-S_60-O_20-ts_100       Tx28  42.0  28.0   2.0  10.0  6.0
# 4   Tx28-L_42-Nb_4-S_60-O_25-ts_85       Tx28  42.0  28.0   2.5   8.5  6.0
#
#     Nb     n_bm1     n_bm2  ...     n_bm4      n_r1      n_r2      n_r3  \
# 0  4.0  0.554060  0.293421  ...  0.000520  0.925505  0.086994  0.026596
# 1  4.0  0.534037  0.298249  ...  0.000889  0.923853  0.093144  0.036185
# 2  4.0  0.586017  0.279188  ...  0.000448  0.993568  0.023006  0.024837
# 3  4.0  0.563802  0.286541  ...  0.000803  0.991692  0.031001  0.033527
# 4  4.0  0.617704  0.265168  ...  0.000379  1.060984 -0.039607  0.022209
#
#        n_r4    sum_RY      d-G1      d-G2      d-G3          d-G4
# 0 -0.039095  0.000035  0.037370  0.016730  0.004557 -1.193530e-34
# 1 -0.053182  0.000035  0.032403  0.015338  0.004701 -1.624839e-34
# 2 -0.041411  0.000030  0.037898  0.015816  0.003978 -1.263675e-34
# 3 -0.056219  0.000035  0.032799  0.014651  0.004199 -1.716785e-34
# 4 -0.043585  0.000036  0.038521  0.014924  0.003400 -1.329766e-34
#
# [5 rows x 21 columns]

# %%
L = df['L']
D = df['D']
S = df['S']
w_oh = df['w_oh']
ts = df['ts']
Nb = df['Nb']
LR = w_oh/S
LD = L/D

n_bm1 = df['n_bm1']
n_bm2 = df['n_bm2']
n_r1 = df['n_r1']
n_r2 = df['n_r2']

# %%
# sample data from lever rule
# n_r1 = (w_oh + S) / S

# %%
X = np.stack((L, w_oh, S, D, Nb, L/D), axis=-1)
y = n_r2

# %%
# Learn equations
default_pysr_params = dict(
    populations=50,
    model_selection="best",
)

# model = PySRRegressor(
#     niterations=30,
#     binary_operators=['+', '-', '*', '/', '^'],
#     unary_operators=["square", "cube", "sqrt"],
#     **default_pysr_params
# )

model = PySRRegressor(
    niterations=200,  # < Increase me for better results
    binary_operators=['+', '-', '*', '/', '^', "physics(x, y) = x^2 / y"],
    unary_operators=["square", "cube", "sqrt", "inv(x) = 1/x"],
        # ^ Custom operator (julia syntax)
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "physics": lambda x, y: x**2 / y},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    constraints = {'^':(-1,1),'mult' : (3,3)},
    # ^ Custom loss function (julia syntax)
    **default_pysr_params
)

model.fit(X, y)

print(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:870: FutureWarning: loss has been renamed to elementwise_loss in PySRRegressor. Please use that instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:1307: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Streaming output truncated to the last 5000 lines.
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           6.568e-04  6.974e-02  y = (0.39904 - sqrt(physics(x₁, x₀))) / 1.6033
# 9           4.800e-04  3.135e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.272e-04  3.831e-01  y = (0.2818 - sqrt(physics(x₁, x₀ * x₅))) / 1.1996
# 12          3.018e-04  4.053e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.731e-04  9.140e-04  y = (0.28357 - sqrt(physics(x₁, x₀ - 0.84398) / x₅)) / (sqrt(p...
#                                   hysics(x₅, x₀) * x₅) - -0.92434)
# 20          2.728e-04  8.185e-04  y = (0.28357 - sqrt(physics(x₁, x₀ - x₅) / x₅)) / ((sqrt(physi...
#                                   cs(sqrt(x₅), x₀)) * x₅) - -0.92434)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.090e+04
# Head worker occupation: 11.1%
# Progress: 2554 / 10000 total iterations (25.540%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           6.568e-04  6.974e-02  y = (0.39904 - sqrt(physics(x₁, x₀))) / 1.6033
# 9           4.800e-04  3.135e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.272e-04  3.831e-01  y = (0.2818 - sqrt(physics(x₁, x₀ * x₅))) / 1.1996
# 12          3.018e-04  4.053e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.729e-04  1.153e-03  y = (0.28357 - sqrt(physics(x₁, x₀ - 0.523) / x₅)) / (sqrt(phy...
#                                   sics(x₅, x₀) * x₅) - -0.92434)
# 20          2.728e-04  3.394e-04  y = (0.28357 - sqrt(physics(x₁, x₀ - x₅) / x₅)) / ((sqrt(physi...
#                                   cs(sqrt(x₅), x₀)) * x₅) - -0.92434)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+04
# Head worker occupation: 11.1%
# Progress: 2592 / 10000 total iterations (25.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           6.568e-04  6.974e-02  y = (0.39904 - sqrt(physics(x₁, x₀))) / 1.6033
# 9           4.800e-04  3.135e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.272e-04  3.831e-01  y = (0.2818 - sqrt(physics(x₁, x₀ * x₅))) / 1.1996
# 12          3.018e-04  4.053e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.634e-04  1.897e-02  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+04
# Head worker occupation: 11.1%
# Progress: 2642 / 10000 total iterations (26.420%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           6.568e-04  6.974e-02  y = (0.39904 - sqrt(physics(x₁, x₀))) / 1.6033
# 9           4.800e-04  3.135e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.28181 - sqrt(physics(x₁, x₅ * x₀))) / 1.2036
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.634e-04  1.897e-02  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.190e+04
# Head worker occupation: 11.1%
# Progress: 2692 / 10000 total iterations (26.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.774e-04  1.986e-01  y = (0.38508 - sqrt(physics(x₁, x₀))) / 1.4996
# 9           4.800e-04  1.847e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.28181 - sqrt(physics(x₁, x₅ * x₀))) / 1.2036
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.634e-04  1.897e-02  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.010e+04
# Head worker occupation: 11.1%
# Progress: 2727 / 10000 total iterations (27.270%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.665e-04  2.176e-01  y = (0.38126 - sqrt(physics(x₁, x₀))) / 1.5536
# 9           4.800e-04  1.657e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.28181 - sqrt(physics(x₁, x₅ * x₀))) / 1.2036
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.634e-04  1.897e-02  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Head worker occupation: 11.1%
# Progress: 2776 / 10000 total iterations (27.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.658e-04  2.189e-01  y = (0.38375 - sqrt(physics(x₁, x₀))) / 1.533
# 9           4.800e-04  1.644e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.28181 - sqrt(physics(x₁, x₅ * x₀))) / 1.2036
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.866e-04  3.974e-02  y = (0.29509 - sqrt(physics(x₁, x₀ + inv(-0.20368)) / x₅)) / (...
#                                   x₅ ^ 0.34634)
# 16          2.781e-04  2.991e-02  y = ((0.28357 - sqrt(physics(x₁, x₀) / x₅)) - (0.84515 ^ x₃)) ...
#                                   / sqrt(sqrt(x₅))
# 17          2.736e-04  1.654e-02  y = (0.28357 - sqrt(physics(x₁, x₀) / x₅)) / (sqrt(physics(x₅,...
#                                    x₀) * x₅) - -0.92434)
# 19          2.634e-04  1.897e-02  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Head worker occupation: 11.0%
# Progress: 2817 / 10000 total iterations (28.170%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.658e-04  2.189e-01  y = (0.38375 - sqrt(physics(x₁, x₀))) / 1.533
# 9           4.800e-04  1.644e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.982e-04  1.619e-03  y = (0.28182 - sqrt(physics(x₁, (x₀ * x₅) + x₁))) / sqrt(sqrt(...
#                                   x₅))
# 15          2.640e-04  1.217e-01  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 19          2.634e-04  6.163e-04  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.860e+04
# Head worker occupation: 11.1%
# Progress: 2853 / 10000 total iterations (28.530%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.658e-04  2.189e-01  y = (0.38375 - sqrt(physics(x₁, x₀))) / 1.533
# 9           4.800e-04  1.644e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.980e-04  2.316e-03  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅) / 0...
#                                   .94851)
# 15          2.640e-04  1.210e-01  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 19          2.634e-04  6.163e-04  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.020e+04
# Head worker occupation: 11.1%
# Progress: 2906 / 10000 total iterations (29.060%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.658e-04  2.189e-01  y = (0.38375 - sqrt(physics(x₁, x₀))) / 1.533
# 9           4.800e-04  1.644e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.980e-04  2.316e-03  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅) / 0...
#                                   .94851)
# 15          2.640e-04  1.210e-01  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 19          2.634e-04  6.163e-04  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.970e+04
# Head worker occupation: 11.0%
# Progress: 2950 / 10000 total iterations (29.500%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.980e-04  2.316e-03  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅) / 0...
#                                   .94851)
# 15          2.640e-04  1.210e-01  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 19          2.634e-04  6.163e-04  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.050e+04
# Head worker occupation: 11.1%
# Progress: 3002 / 10000 total iterations (30.020%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.980e-04  2.316e-03  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅) / 0...
#                                   .94851)
# 15          2.640e-04  1.210e-01  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 19          2.634e-04  6.163e-04  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.260e+04
# Head worker occupation: 11.1%
# Progress: 3056 / 10000 total iterations (30.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 11          3.271e-04  -0.000e+00  y = sqrt(0.69045) * (0.2818 - sqrt(physics(x₁, x₅ * x₀)))
# 12          3.018e-04  8.076e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.794e-04  6.662e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 19          2.634e-04  6.163e-04  y = (0.27648 - sqrt(physics(x₁ * -0.93705, x₀ - cube(x₅)) / x₅...
#                                   )) / ((x₅ / x₃) - -1.1249)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.120e+04
# Head worker occupation: 11.2%
# Progress: 3092 / 10000 total iterations (30.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.794e-04  6.662e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 18          2.617e-04  2.916e-03  y = (0.29509 - sqrt((physics(x₁, x₀ - cube(x₅)) / x₅) * inv(1....
#                                   0135))) / (x₅ ^ 0.34634)
# 20          2.556e-04  1.189e-02  y = (0.29509 - sqrt(physics(x₁, (x₀ - cube(x₅)) + -1.1051) / x...
#                                   ₅)) / sqrt((x₅ / 0.73354) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.030e+04
# Head worker occupation: 11.3%
# Progress: 3136 / 10000 total iterations (31.360%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.794e-04  6.662e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 18          2.617e-04  2.916e-03  y = (0.29509 - sqrt((physics(x₁, x₀ - cube(x₅)) / x₅) * inv(1....
#                                   0135))) / (x₅ ^ 0.34634)
# 20          2.556e-04  1.189e-02  y = (0.29509 - sqrt(physics(x₁, (x₀ - cube(x₅)) + -1.1051) / x...
#                                   ₅)) / sqrt((x₅ / 0.73354) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.910e+04
# Head worker occupation: 11.2%
# Progress: 3169 / 10000 total iterations (31.690%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          3.018e-04  4.038e-02  y = (0.28308 - sqrt(physics(x₁, x₀) / x₅)) / sqrt(sqrt(x₅))
# 13          2.987e-04  1.031e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (square(x₅) ^ 0.1...
#                                   3414)
# 14          2.794e-04  6.662e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 18          2.617e-04  2.916e-03  y = (0.29509 - sqrt((physics(x₁, x₀ - cube(x₅)) / x₅) * inv(1....
#                                   0135))) / (x₅ ^ 0.34634)
# 20          2.543e-04  1.432e-02  y = (0.29509 - sqrt(physics(x₁, (x₀ - cube(x₅)) + -0.17467) / ...
#                                   x₅)) / sqrt((x₅ / 0.73354) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.770e+04
# Head worker occupation: 11.2%
# Progress: 3206 / 10000 total iterations (32.060%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.979e-04  4.680e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.27498)
# 14          2.794e-04  3.204e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 17          2.640e-04  5.737e-05  y = (0.29509 - sqrt(physics(x₁, (x₀ - cube(x₅)) - -0.09783) / ...
#                                   x₅)) / (x₅ ^ 0.34634)
# 18          2.546e-04  3.630e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / 0.73354) ^ 0.45517)
# 20          2.543e-04  4.803e-04  y = (0.29509 - sqrt(physics(x₁, (x₀ - cube(x₅)) + -0.17467) / ...
#                                   x₅)) / sqrt((x₅ / 0.73354) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+04
# Head worker occupation: 11.2%
# Progress: 3261 / 10000 total iterations (32.610%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.794e-04  3.153e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 17          2.555e-04  1.646e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(s...
#                                   qrt(1.4808) ^ x₅)
# 18          2.546e-04  3.498e-03  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / 0.73354) ^ 0.45517)
# 20          2.542e-04  7.517e-04  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / (0.73354 ^ 0.68042)) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.960e+04
# Head worker occupation: 11.1%
# Progress: 3306 / 10000 total iterations (33.060%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.794e-04  3.153e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 17          2.555e-04  1.646e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(s...
#                                   qrt(1.4808) ^ x₅)
# 18          2.546e-04  3.498e-03  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / 0.73354) ^ 0.45517)
# 20          2.542e-04  7.517e-04  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / (0.73354 ^ 0.68042)) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.090e+04
# Head worker occupation: 11.1%
# Progress: 3356 / 10000 total iterations (33.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.794e-04  3.153e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.640e-04  5.666e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.34634)
# 17          2.555e-04  1.646e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(s...
#                                   qrt(1.4808) ^ x₅)
# 18          2.546e-04  3.498e-03  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / 0.73354) ^ 0.45517)
# 20          2.538e-04  1.458e-03  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / (0.73354 ^ 0.94625)) ^ 0.45517)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.290e+04
# Head worker occupation: 11.1%
# Progress: 3412 / 10000 total iterations (34.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.794e-04  3.153e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.585e-04  7.768e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.28461)
# 17          2.555e-04  5.950e-03  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(s...
#                                   qrt(1.4808) ^ x₅)
# 18          2.546e-04  3.498e-03  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt((...
#                                   x₅ / 0.73354) ^ 0.45517)
# 20          2.534e-04  2.344e-03  y = (0.39724 - sqrt(physics(x₁ - -0.71219, physics(x₅ * x₃, x₀...
#                                   ) * sqrt(x₅)))) / square(sqrt(sqrt(x₅)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.220e+04
# Head worker occupation: 11.1%
# Progress: 3447 / 10000 total iterations (34.470%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.794e-04  3.153e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / sqrt(1...
#                                   .4808)
# 15          2.585e-04  7.768e-02  y = (0.29509 - sqrt(physics(x₁, x₀ - cube(x₅)) / x₅)) / (x₅ ^ ...
#                                   0.28461)
# 16          2.534e-04  2.009e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, x₀ * sqrt(x₅)))) / ...
#                                   square(sqrt(sqrt(x₅)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.130e+04
# Head worker occupation: 11.1%
# Progress: 3500 / 10000 total iterations (35.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.534e-04  8.041e-02  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 18          2.534e-04  5.960e-08  y = (0.39724 - sqrt(physics(x₁ - -0.71219, sqrt(x₅) * x₀))) / ...
#                                   square(square(sqrt(sqrt(sqrt(x₅)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.250e+04
# Head worker occupation: 11.1%
# Progress: 3551 / 10000 total iterations (35.510%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           4.788e-02  1.594e+01  y = 0.25402
# 2           7.152e-03  1.901e+00  y = square(-0.2285)
# 3           4.092e-03  5.585e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.630e-04  2.238e-01  y = (0.38125 - sqrt(physics(x₁, x₀))) / 1.5241
# 9           4.800e-04  1.595e-01  y = (0.29192 - physics(1.2933 + x₁, x₀)) * 0.62059
# 10          3.271e-04  3.834e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.732e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28461)
# 14          2.534e-04  8.041e-02  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 18          2.534e-04  5.960e-08  y = (0.39724 - sqrt(physics(x₁ - -0.71219, sqrt(x₅) * x₀))) / ...
#                                   square(square(sqrt(sqrt(sqrt(x₅)))))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.080e+04
# Head worker occupation: 11.1%
# ...
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.120e+04
# Head worker occupation: 10.2%
# Progress: 9765 / 10000 total iterations (97.650%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.152e-03  1.594e+01  y = 0.052218
# 3           4.092e-03  2.792e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.629e-04  2.240e-01  y = (0.38071 - sqrt(physics(x₁, x₀))) * 0.65778
# 9           4.797e-04  1.599e-01  y = 0.62457 * (0.29156 - physics(x₁ + 1.2941, x₀))
# 10          3.271e-04  3.829e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.734e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28335)
# 13          2.940e-04  1.224e-02  y = (0.39724 - sqrt(physics(-0.76557 - x₁, sqrt(x₅) * x₀))) / ...
#                                   1.4091
# 14          2.534e-04  1.485e-01  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 15          2.518e-04  6.136e-03  y = (0.39724 - sqrt(physics(-0.72839 - x₁, (x₅ ^ 0.51525) * x₀...
#                                   ))) / sqrt(x₅)
# 16          2.426e-04  3.717e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt(1.4091 ^ x₅)
# 18          2.424e-04  5.023e-04  y = (0.39724 - sqrt(physics(-0.71219 - x₁, (sqrt(x₅) * x₀) * 0...
#                                   .99298))) / (sqrt(1.4091) ^ x₅)
# 19          2.421e-04  1.154e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅ + cube(-0.2...
#                                   5616)) * x₀))) / sqrt(1.4091 ^ x₅)
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Head worker occupation: 10.3%
# Progress: 9815 / 10000 total iterations (98.150%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.152e-03  1.594e+01  y = 0.052218
# 3           4.092e-03  2.792e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.629e-04  2.240e-01  y = (0.38071 - sqrt(physics(x₁, x₀))) * 0.65778
# 9           4.797e-04  1.599e-01  y = 0.62457 * (0.29156 - physics(x₁ + 1.2941, x₀))
# 10          3.271e-04  3.829e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.734e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28335)
# 13          2.940e-04  1.224e-02  y = (0.39724 - sqrt(physics(-0.76557 - x₁, sqrt(x₅) * x₀))) / ...
#                                   1.4091
# 14          2.534e-04  1.485e-01  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 15          2.518e-04  6.136e-03  y = (0.39724 - sqrt(physics(-0.72839 - x₁, (x₅ ^ 0.51525) * x₀...
#                                   ))) / sqrt(x₅)
# 16          2.426e-04  3.717e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt(1.4091 ^ x₅)
# 18          2.424e-04  5.023e-04  y = (0.39724 - sqrt(physics(-0.71219 - x₁, (sqrt(x₅) * x₀) * 0...
#                                   .99298))) / (sqrt(1.4091) ^ x₅)
# 19          2.421e-04  1.154e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅ + cube(-0.2...
#                                   5616)) * x₀))) / sqrt(1.4091 ^ x₅)
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+04
# Head worker occupation: 10.3%
# Progress: 9860 / 10000 total iterations (98.600%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.152e-03  1.594e+01  y = 0.052218
# 3           4.092e-03  2.792e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.629e-04  2.240e-01  y = (0.38071 - sqrt(physics(x₁, x₀))) * 0.65778
# 9           4.797e-04  1.599e-01  y = 0.62457 * (0.29156 - physics(x₁ + 1.2941, x₀))
# 10          3.271e-04  3.829e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.734e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28335)
# 13          2.940e-04  1.224e-02  y = (0.39724 - sqrt(physics(-0.76557 - x₁, sqrt(x₅) * x₀))) / ...
#                                   1.4091
# 14          2.534e-04  1.485e-01  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 15          2.518e-04  6.136e-03  y = (0.39724 - sqrt(physics(-0.72839 - x₁, (x₅ ^ 0.51525) * x₀...
#                                   ))) / sqrt(x₅)
# 16          2.426e-04  3.717e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt(1.4091 ^ x₅)
# 18          2.424e-04  5.023e-04  y = (0.39724 - sqrt(physics(-0.71219 - x₁, (sqrt(x₅) * x₀) * 0...
#                                   .99298))) / (sqrt(1.4091) ^ x₅)
# 19          2.421e-04  1.154e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅ + cube(-0.2...
#                                   5616)) * x₀))) / sqrt(1.4091 ^ x₅)
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Head worker occupation: 10.3%
# Progress: 9901 / 10000 total iterations (99.010%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.152e-03  1.594e+01  y = 0.052218
# 3           4.092e-03  2.792e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.629e-04  2.240e-01  y = (0.38071 - sqrt(physics(x₁, x₀))) * 0.65778
# 9           4.797e-04  1.599e-01  y = 0.62457 * (0.29156 - physics(x₁ + 1.2941, x₀))
# 10          3.271e-04  3.829e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.734e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28335)
# 13          2.940e-04  1.224e-02  y = (0.39724 - sqrt(physics(-0.76557 - x₁, sqrt(x₅) * x₀))) / ...
#                                   1.4091
# 14          2.534e-04  1.485e-01  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 15          2.518e-04  6.136e-03  y = (0.39724 - sqrt(physics(-0.72839 - x₁, (x₅ ^ 0.51525) * x₀...
#                                   ))) / sqrt(x₅)
# 16          2.426e-04  3.717e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt(1.4091 ^ x₅)
# 18          2.424e-04  5.023e-04  y = (0.39724 - sqrt(physics(-0.71219 - x₁, (sqrt(x₅) * x₀) * 0...
#                                   .99298))) / (sqrt(1.4091) ^ x₅)
# 19          2.421e-04  1.154e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅ + cube(-0.2...
#                                   5616)) * x₀))) / sqrt(1.4091 ^ x₅)
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.110e+04
# Head worker occupation: 10.3%
# Progress: 9952 / 10000 total iterations (99.520%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.152e-03  1.594e+01  y = 0.052218
# 3           4.092e-03  2.792e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.629e-04  2.240e-01  y = (0.38071 - sqrt(physics(x₁, x₀))) * 0.65778
# 9           4.797e-04  1.599e-01  y = 0.62457 * (0.29156 - physics(x₁ + 1.2941, x₀))
# 10          3.271e-04  3.829e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.734e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28335)
# 13          2.940e-04  1.224e-02  y = (0.39724 - sqrt(physics(-0.76557 - x₁, sqrt(x₅) * x₀))) / ...
#                                   1.4091
# 14          2.534e-04  1.485e-01  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 15          2.518e-04  6.136e-03  y = (0.39724 - sqrt(physics(-0.72839 - x₁, (x₅ ^ 0.51525) * x₀...
#                                   ))) / sqrt(x₅)
# 16          2.426e-04  3.717e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt(1.4091 ^ x₅)
# 18          2.424e-04  5.023e-04  y = (0.39724 - sqrt(physics(-0.71219 - x₁, (sqrt(x₅) * x₀) * 0...
#                                   .99298))) / (sqrt(1.4091) ^ x₅)
# 19          2.421e-04  1.154e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅ + cube(-0.2...
#                                   5616)) * x₀))) / sqrt(1.4091 ^ x₅)
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.000e+04
# Head worker occupation: 10.3%
# Progress: 9986 / 10000 total iterations (99.860%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           7.152e-03  1.594e+01  y = 0.052218
# 3           4.092e-03  2.792e-01  y = 0.29835 ^ x₁
# 5           8.227e-04  8.021e-01  y = 0.15824 - physics(x₁, x₀)
# 7           7.042e-04  7.776e-02  y = 0.14868 - physics(x₁ ^ 0.96212, x₀)
# 8           5.629e-04  2.240e-01  y = (0.38071 - sqrt(physics(x₁, x₀))) * 0.65778
# 9           4.797e-04  1.599e-01  y = 0.62457 * (0.29156 - physics(x₁ + 1.2941, x₀))
# 10          3.271e-04  3.829e-01  y = (0.2818 - sqrt(physics(x₁, x₀) / x₅)) * 0.83092
# 12          2.976e-04  4.734e-02  y = (0.28461 - sqrt(physics(x₁, x₀) / x₅)) / (x₅ ^ 0.28335)
# 13          2.940e-04  1.224e-02  y = (0.39724 - sqrt(physics(-0.76557 - x₁, sqrt(x₅) * x₀))) / ...
#                                   1.4091
# 14          2.534e-04  1.485e-01  y = (0.39724 - sqrt(physics(x₁ - -0.71219, x₀ * sqrt(x₅)))) / ...
#                                   sqrt(x₅)
# 15          2.518e-04  6.136e-03  y = (0.39724 - sqrt(physics(-0.72839 - x₁, (x₅ ^ 0.51525) * x₀...
#                                   ))) / sqrt(x₅)
# 16          2.426e-04  3.717e-02  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt(1.4091 ^ x₅)
# 18          2.424e-04  5.023e-04  y = (0.39724 - sqrt(physics(-0.71219 - x₁, (sqrt(x₅) * x₀) * 0...
#                                   .99298))) / (sqrt(1.4091) ^ x₅)
# 19          2.421e-04  1.154e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅ + cube(-0.2...
#                                   5616)) * x₀))) / sqrt(1.4091 ^ x₅)
# 20          2.405e-04  6.854e-03  y = (0.39724 - sqrt(physics(-0.71219 - x₁, sqrt(x₅) * x₀))) / ...
#                                   sqrt((1.3965 + (0.95396 ^ x₀)) ^ x₅)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                        0.052217618
# 	1         0.279230                                     0.2983516 ^ x1
# 	2         0.802078                       0.15824491 - physics(x1, x0)
# 	3         0.077756           0.1486804 - physics(x1 ^ 0.96211624, x0)
# 	4         0.223968    (0.380709 - sqrt(physics(x1, x0))) * 0.65777886
# 	5         0.159893  0.62456733 * (0.29156217 - physics(x1 + 1.2941...
# 	6   >>>>  0.382853  (0.28179651 - sqrt(physics(x1, x0) / x5)) * 0....
# 	7         0.047335  (0.28461385 - sqrt(physics(x1, x0) / x5)) / (x...
# 	8         0.012240  (0.39723516 - sqrt(physics(-0.7655697 - x1, sq...
# 	9         0.148539  (0.39723516 - sqrt(physics(x1 - -0.71218735, x...
# 	10        0.006136  (0.39723516 - sqrt(physics(-0.7283924 - x1, (x...
# 	11        0.037166  (0.39723516 - sqrt(physics(-0.71218735 - x1, s...
# 	12        0.000502  (0.39723516 - sqrt(physics(-0.71218735 - x1, (...
# 	13        0.001154  (0.39723516 - sqrt(physics(-0.71218735 - x1, s...
# 	14        0.006854  (0.39723516 - sqrt(physics(-0.71218735 - x1, s...
#
# 	        loss  complexity
# 	0   0.007152           1
# 	1   0.004092           3
# 	2   0.000823           5
# 	3   0.000704           7
# 	4   0.000563           8
# 	5   0.000480           9
# 	6   0.000327          10
# 	7   0.000298          12
# 	8   0.000294          13
# 	9   0.000253          14
# 	10  0.000252          15
# 	11  0.000243          16
# 	12  0.000242          18
# 	13  0.000242          19
# 	14  0.000240          20
# ]

# %%
model.sympy(6)
# Out:
# 0.234150412448502 - 0.8309202*sqrt(x1**2/(x0*x5))

# %%
n_r2_pred = model.predict(X,6)

print("Default selection MSE:", np.power(n_r2_pred - y, 2).mean())
# Out:
# Default selection MSE: 8.995784488485084e-05

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Generate some example data
x = n_r2
y = n_r2_pred

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Calculate the regression line
line = slope * x + intercept

# Sort the values for proper shading
sort_idx = np.argsort(x)
x_sorted = x[sort_idx]
line_sorted = line[sort_idx]

# Calculate the prediction interval
mean_x = np.mean(x)
n = len(x)
t = stats.t.ppf(0.975, n - 2)
sum_errs = np.sum((y - line) ** 2)
stdev = np.sqrt(1/(n-2) * sum_errs)

# Prediction interval calculation
pi = t * stdev * np.sqrt(1 + 1/n + (x_sorted - mean_x)**2 / np.sum((x_sorted - mean_x)**2))

# Plot the scatter plot, regression line, and prediction intervals
plt.figure(figsize=(5, 5))
plt.scatter(x, y, marker='x', c='b', edgecolor='b', label='Interior Girder')
plt.plot(x_sorted, line_sorted, color='red', label='Linear fit')
plt.fill_between(x_sorted, line_sorted - pi, line_sorted + pi, color='red', alpha=0.2, label='95% prediction interval')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Fit with 95% Prediction Interval')
plt.legend()
plt.xlim((-0.4,0.4))
plt.ylim((-0.4,0.4))
plt.show()
# Out:
# <ipython-input-251-4e11c675977e>:32: UserWarning: You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x, y, marker='x', c='b', edgecolor='b', label='Interior Girder')

# %%
x_line = [-0.2, 0.6]
y_line = [-0.2, 0.6]

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), constrained_layout = True)

ax1.scatter(x=n_bm2, y=n_bm2_pred, marker='o', c='none', edgecolor='r', label='Exterior Girder')
ax1.plot(x_line, y_line, c = "k")
ax1.set_title('Accuracy')
ax1.legend()
plt.xlim((-0.2,0.6))
plt.ylim((-0.2,0.6))
ax1.set_xlabel('Target $n_{r1}$')
ax1.set_ylabel('Predicted $n_{r1}$')
ax1.grid()
